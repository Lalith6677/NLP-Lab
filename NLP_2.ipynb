# %% [markdown]
# <a href="https://colab.research.google.com/github/Lalith6677/NLP-Lab/blob/main/NLP_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reading from text file

# %%
import pandas as pd
import csv

# %%
output= pd.read_csv("/content/files.txt",sep='\t')
print(output)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-773680405.py in <cell line: 0>()
# ----> 1 output= pd.read_csv("/content/files.txt",sep='\t')
#       2 print(output)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
with open ('/content/files.txt','r',encoding = 'utf-8') as f:
  text=f.read()
  print(text)

# %%
output= pd.read_csv("/content/spam.csv")
print(output)

# %%
with open ('/content/spam.csv','r',encoding = 'utf-8') as f:
  text=f.read()
  print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2213614706.py in <cell line: 0>()
# ----> 1 with open ('/content/spam.csv','r',encoding = 'utf-8') as f:
#       2   text=f.read()
#       3   print(text)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/spam.csv'

# %%
# !pip install PyPDF2

import PyPDF2
PDF_file = open('/content/report.pdf','rb')
reader=PyPDF2.PdfReader(PDF_file)
text=""
for page in reader.pages:
  text+=page.extract_text()
print(text)
PDF_file.close()

# %%
import requests
from bs4 import BeautifulSoup

# %%
input=requests.get('https://en.wikipedia.org/wiki/Natural_language_processing')
print(input)

# %%
input=requests.get('https://ubuntu.com/')
print(input)

# %%
input.content

# %%
sb=BeautifulSoup(input.content,'html.parser')
print(sb)

# %%
sb=BeautifulSoup(input.content,'html.parser')
sb.find_all('p')

# %%
data['hash_tags_counts']=data['tweets'].apply(lambda x:len(re.findall(r'#\w+',x)))
