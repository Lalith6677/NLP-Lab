# %% [markdown]
# <a href="https://colab.research.google.com/github/Lalith6677/NLP-Lab/blob/main/NLP5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
para = "The Porsche 911 GT3 is a high-performance homologation model of the Porsche 911 sports car. It is a range of high-performance models, which began with the 1973 911 Carrera RS. The GT3 has had a successful racing career in the one-make national and regional Porsche Carrera Cup and GT3 Cup Challenge series, as well as the international Porsche Supercup supporting the FIA F1 World Championship"
sentence = nltk.sent_tokenize(para)

# %%
sentence
# Out:
# ['The Porsche 911 GT3 is a high-performance homologation model of the Porsche 911 sports car.',
#  'It is a range of high-performance models, which began with the 1973 911 Carrera RS.',
#  'The GT3 has had a successful racing career in the one-make national and regional Porsche Carrera Cup and GT3 Cup Challenge series, as well as the international Porsche Supercup supporting the FIA F1 World Championship']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
for i in range(len(sentence)):
  words = nltk.word_tokenize(sentence[i])
  words = [stemmer.stem(word) for word in words ]
  sentence[i] = ' '.join(words)

# %%
sentence
# Out:
# ['the porsch 911 gt3 is a high-perform homolog model of the porsch 911 sport car .',
#  'it is a rang of high-perform model , which began with the 1973 911 carrera rs .',
#  'the gt3 ha had a success race career in the one-mak nation and region porsch carrera cup and gt3 cup challeng seri , as well as the intern porsch supercup support the fia f1 world championship']

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
para = "The Porsche 911 GT3 is a high-performance homologation model of the Porsche 911 sports car. It is a range of high-performance models, which began with the 1973 911 Carrera RS. The GT3 has had a successful racing career in the one-make national and regional Porsche Carrera Cup and GT3 Cup Challenge series, as well as the international Porsche Supercup supporting the FIA F1 World Championship"
sentence1 = nltk.sent_tokenize(para)
sentence1
# Out:
# ['The Porsche 911 GT3 is a high-performance homologation model of the Porsche 911 sports car.',
#  'It is a range of high-performance models, which began with the 1973 911 Carrera RS.',
#  'The GT3 has had a successful racing career in the one-make national and regional Porsche Carrera Cup and GT3 Cup Challenge series, as well as the international Porsche Supercup supporting the FIA F1 World Championship']

# %%
for i in range(len(sentence1)):
  words = nltk.word_tokenize(sentence[i])
  newwords = [lemmatizer.lemmatize(word) for word in words ]
  sentence1[i] = ' '.join(newwords)

# %%
sentence1
# Out:
# ['the porsch 911 gt3 is a high-perform homolog model of the porsch 911 sport car .',
#  'it is a rang of high-perform model , which began with the 1973 911 carrera r .',
#  'the gt3 ha had a success race career in the one-mak nation and region porsch carrera cup and gt3 cup challeng seri , a well a the intern porsch supercup support the fia f1 world championship']

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.pos_tag(word_tokenize(para))
wordss = word_tokenize(para)
tag = nltk.pos_tag(wordss)

# %%
tag
# Out:
# [('The', 'DT'),
#  ('Porsche', 'NNP'),
#  ('911', 'CD'),
#  ('GT3', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-performance', 'JJ'),
#  ('homologation', 'NN'),
#  ('model', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Porsche', 'NNP'),
#  ('911', 'CD'),
#  ('sports', 'NNS'),
#  ('car', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('high-performance', 'NN'),
#  ('models', 'NNS'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('began', 'VBD'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('1973', 'CD'),
#  ('911', 'CD'),
#  ('Carrera', 'NNP'),
#  ('RS', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('GT3', 'NNP'),
#  ('has', 'VBZ'),
#  ('had', 'VBD'),
#  ('a', 'DT'),
#  ('successful', 'JJ'),
#  ('racing', 'NN'),
#  ('career', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('one-make', 'JJ'),
#  ('national', 'JJ'),
#  ('and', 'CC'),
#  ('regional', 'JJ'),
#  ('Porsche', 'NNP'),
#  ('Carrera', 'NNP'),
#  ('Cup', 'NNP'),
# ...

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('maxent_ne_chunker_tab')
named_Ent = nltk.ne_chunk(tag)
named_Ent
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker_tab.zip.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.12/dist-packages/nltk/tree/tree.py in _repr_svg_(self)
#     780
# ...

# %%
# !pip install svgling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 5.1 MB/s eta 0:00:00
# ...
